# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
foldername= "/content/drive/My Drive/IS/multi_nli3/multi_nli3_result/"

# %%
import csv
import pandas as pd

# %%
result_dict={
    #conditions
    "index":[],#
    "digit":[],#                   used for zeroshot_fi and fewshot_fi
    "num_example":[],#         (0, 1,3 ,5)                                                          used for fewshot (one shot included)
    "model":[],#[gpt4, 3.5]
    "general_scenario": [],# ["1", "2", "3", "4"]               read setups

    #result
    "accuracy":[],#prob of choosing correct answer
    "correct_ratio":[],#prob of choosing correct answer when choosing one of the desired target words
    "unknown_rate":[],#prob of not choosing yes nor no
    "rlr":[],   #read setups

}

# %%
#baseline_result=pd.DataFrame(result_dict)
#baseline_result.to_csv(foldername+"multi_nli_zeroshot_result.csv")

# %%
result=pd.DataFrame(result_dict)
general_scenarios= ["zeroshot_fi", "zeroshot_nfi", "fewshot_fi", "fewshot_nfi"]
experiments= ["mass_list_result", "mass_dict_result", "mass_base_result", "list_result", "dict_result", "base_result"]
for x in experiments:
  path=foldername+"multi_nli3_result_"+x+"/"
  for y in general_scenarios:
    result.to_csv(path+x+"_"+y+".csv")
