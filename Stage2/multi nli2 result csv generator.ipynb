# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
foldername= "/content/drive/My Drive/IS/multi_nli2/multi_nli2_result/"

# %%
import csv
import pandas as pd

# %%
result_dict={
    #conditions
    "index":[],#
    "scenario":[],#["zeroshot_fi", "zeroshot_nfi", "fewshot_fi", "fewshot_mfi"]     
    "general_scenario": [],# ["1", "2", "3", "4"]               read setups
    "digit":[],#     
    "task_instruction":[],# 2 different ways of describing the task
    "format_instruction":[],# 3 different ways of describing the format               used for zeroshot_fi and fewshot_fi

    "num_example":[],#                                                                used for fewshot (one shot included)
    "model":[],#[gpt4, 3.5]

    #result
    "accuracy":[],#prob of choosing correct answer
    "correct_ratio":[],#prob of choosing correct answer when choosing one of the desired target words
    "unknown_rate":[],#prob of not choosing yes nor no
    "wrong_rate":[],#prob of choosing incorrect answer
    "rlr":[],   #read setups
    "f1":[]

}

# %%
#baseline_result=pd.DataFrame(result_dict)
#baseline_result.to_csv(foldername+"multi_nli_zeroshot_result.csv")

# %%
result=pd.DataFrame(result_dict)
general_scenarios= ["zeroshot_fi", "zeroshot_nfi", "fewshot_fi", "fewshot_nfi"]
for x in general_scenarios:
  result.to_csv(foldername+"multi_nli2_result_"+x+".csv")
